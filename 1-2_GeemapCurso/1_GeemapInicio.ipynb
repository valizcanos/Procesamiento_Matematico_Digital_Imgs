# %% [markdown]
# # Importar Geemap

# %%
import geemap
import ee

# %% [markdown]
# ## Ahora procedemos a autenticar los datos de nuestra cuenta de gmail y GEE para utilizar geemap. Este procedimiento lo puede realizar una única vez en su computadora. Después de ello su cuenta queda auntenticada

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#ee.Authenticate() #Ejecutar una sola vez

# %% [markdown]
# ## Inicialización de Geemap

# %%
ee.Initialize()

# %% [markdown]
# ## Activar el visor de imágenes

# %%
Map = geemap.Map()

# %%
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…
